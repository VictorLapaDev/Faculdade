# %% [markdown]
# ![image.png](attachment:247543ec-5fcf-4312-a924-d5827ffa8095.png)

# %% [markdown]
# # Bibliotecas Principais
#
# 1. **Matplotlib**: Biblioteca base para criação de gráficos
# 2. **Seaborn**: Melhora esteticamente os gráficos do Matplotlib e simplifica visualizações estatísticas
# 3. **Plotly**: Cria visualizações interativas e dinâmicas
# 4. **Pandas Plotting**: Integração direta com DataFrames
# 5. **Geopandas**: Especializada em visualização geográfica

# %% [markdown]
# ## 1. Gráfico de linhas
# ##### Sintaxe básica:
# ``` Python
#     plt.plot(x, y)

# %%
import matplotlib.pyplot as plt

x = [5,6,7,8,9]
y = [12,14,16,18,20]

plt.plot(x, y)
plt.title('Gráfico de linha - Simples')
plt.xlabel('Eixo das abcissas')
plt.ylabel('Eixo das Ordenadas')
plt.show()

# %%
import numpy as np

x = np.arange(0,10,0.01)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# #### Gráfico de linhas (adicionando elementos)

# %%
plt.figure(figsize = (10,6), dpi = 300)  # DPI: Dots Per Int - É uma mediade de densidade que define a qualidade da figura
plt.plot(x,y, color='chartreuse', linewidth = 3, label = 'Seno')
plt.title('Gráfico da função Seno', color='blue',fontsize=17)
plt.xlabel('Eixo X', fontsize=15)
plt.ylabel('Eixo Y', fontsize=15)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 2. Gráficos Multiplos e Subplot
# #### Gráficos em uma mesma figura
# - Com a função subplots (), você pode desenhar vários gráficos em uma figura:
# - Nesse primeiro exemplo, vamos plotar dois sub gráficos de linhas

# %%
plt.figure(figsize = (10,6), dpi = 150)

plt.subplot(1,2,1) #Linha, coluna, indice
plt.title('Posição do gráfico 1')

plt.subplot(1,2,2)
plt.title('Posição do gráfico 2')

plt.show()

# %% [markdown]
# ### Gráficos lado a lado

# %%
plt.figure(figsize = (10,6))

x = np.arange(0,10,0.1)
y = np.cos(x)
plt.subplot(1,2,1) 
plt.plot(x,y, color ='r')

x = np.arange(0,10,0.2)
y = np.sin(x)
plt.subplot(1,2,2)
plt.plot(x,y, color='y')

plt.show()

# %% [markdown]
# ### Gráfico um em cima do outro

# %%
plt.figure(figsize = (10,6))

x = np.arange(0,10,0.1)
y = np.cos(x)
plt.subplot(2,1,1) 
plt.plot(x,y, color ='r')

x = np.arange(0,10,0.2)
y = np.sin(x)
plt.subplot(2,1,2)
plt.plot(x,y, color='y')

plt.show()

# %% [markdown]
# ### Múltiplos Gráficos com Subplot
# - É possível plotar quantos gráficos quiser em uma figura, só precisar informar a quantidade de linhas e colunas que terá a figura, além do índice do gráfico.

# %%
plt.figure(figsize = (10,6))
x = np.arange(0,10,0.1)
y = np.cos(x)

for i in range(1,5):
    plt.subplot(2,2,i) 
    plt.plot(x,y, color ='c')

plt.show()

# %%
plt.figure(figsize = (10,6))

x = np.arange(0,10,0.1)
y = np.cos(x)
plt.subplot(2,2,1) 
plt.plot(x,y, color ='c')

x = np.arange(0,10,0.2)
y = np.sin(x)
plt.subplot(2,2,2)
plt.plot(x,y, color='m')

x = np.arange(0,10,0.1)
y = np.tan(x)
plt.subplot(2,2,3) 
plt.plot(x,y, color ='y')

x = np.arange(0,10,0.2)
y = np.sinh(x)
plt.subplot(2,2,2)
plt.plot(x,y, color='k')

plt.show()

# %% [markdown]
# ### 3. Visualização de Dados Numéricos
# #### Histograma

# %%
data = np.random.normal(0,1,1000)

# %%
plt.figure(figsize = (8,6))

plt.hist(data, bins=50, color='royalblue',edgecolor='navy', alpha = 0.5)
plt.title('Distribuição de Dados - Histograma')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize = (8,6))
sns.histplot(data, bins=50, kde=True)  # KDE: kernel Density Estimation
#kde é uma curva contínua suavidada que aproxima a distribuição subjacente dos dados
plt.title('Distribuição de Dados - Histograma')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# ### 4. Gráficos boxplot com Matplotlib e Seaborn
# - Exemplos de boxplot, com a base de dados flores iris, que tem 3 tipos de flores

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize = (8,6))
sns.boxplot(x='species',y='petal_length', data=df, width=0.3, hue='species', palette ='plasma')
# hue cria categoria e tipifica com cores diferentes
plt.title('Boxplot do dataset Iris')
plt.xlabel('Espécies')
plt.ylabel('Comprimento da Pétala')
plt.show()

# %% [markdown]
# ### Mult Boxplot com Matplotlib

# %%
setosa = df[df['species']=='setosa']['petal_length']
versicolor = df[df['species']=='versicolor']['petal_length']
virginica = df[df['species']=='virginica']['petal_length']

dados = [setosa, versicolor, virginica]

# %%
plt.figure(figsize = (8,6))
box = plt.boxplot(dados, tick_labels = ['setosa', 'versicolor', 'virginica'],
                 patch_artist=True)

for patch, cor in zip(box['boxes'],['r','g','b']):
    patch.set_facecolor(cor)
    
plt.title('Boxplot do dataset Iris')
plt.xlabel('Espécies')
plt.ylabel('Comprimento da Pétala')
plt.show()

# %% [markdown]
# #### Formatando por partes

# %%
plt.figure(figsize = (8,6))
box = plt.boxplot(dados, patch_artist=True, vert=False)

cores = ['gold', 'aqua', 'lime']
cores_w = ['gold','gold', 'aqua','aqua', 'lime','lime']

# 1. Contorno das caixas
for i, bplot in enumerate(box['boxes']):
    bplot.set(color=cores[i], linewidth=3)

# 2. Whiskers (2 por caixa)
for i, whiskers in enumerate(box['whiskers']):
    whiskers.set(color=cores_w[i], linewidth=3)

# 3. Caps (extremidades)
for i, caps in enumerate(box['caps']):
    caps.set(color=cores_w[i], linewidth=3)

# 4. Medianas
for i, median in enumerate(box['medians']):
    median.set(color=cores[i], linewidth=3)

plt.title('Boxplot do dataset Iris')
plt.xlabel('Espécies')
plt.ylabel('Comprimento da Pétala')
plt.show()

# %% [markdown]
# ### Mult Boxplot com Matplotlib Cor

# %%
plt.figure(figsize = (8,6))
box = plt.boxplot(dados, notch=True, patch_artist=True, vert=True)
# Notch=True : Ativa o boxplot com entalhe (notched boxplot)

cores = ['gold', 'aqua', 'lime']
cores_w = ['gold','orange', 'aqua','blue', 'lime','green']

# 1. Contorno das caixas
for i, bplot in enumerate(box['boxes']):
    bplot.set(color='gray', linewidth=3)
    bplot.set(facecolor=cores[i])

# 2. Whiskers (2 por caixa)
for i, whiskers in enumerate(box['whiskers']):
    whiskers.set(color='gray', linewidth=3)

# 3. Caps (extremidades)
for i, caps in enumerate(box['caps']):
    caps.set(color='gray', linewidth=3)

# 4. Medianas
for i, median in enumerate(box['medians']):
    median.set(color='gray', linewidth=3)

plt.title('Boxplot do dataset Iris')
plt.xlabel('Espécies')
plt.ylabel('Comprimento da Pétala')
plt.show()

# %% [markdown]
# ### Boxplot, Gráfico de Disperção com Seaborn

# %%
plt.figure(figsize = (8,6))
ax = sns.boxplot(x='species',y='petal_length', data=df, width=0.3, hue='species', palette ='magma', linewidth=3)

#ax = sns.stripplot(x='species',y='petal_length', hue='species', data=df)
ax = sns.swarmplot(x='species',y='petal_length', hue='species', data=df)

plt.title('Boxplot do dataset Iris')
plt.xlabel('Espécies')
plt.ylabel('Comprimento da Pétala')
plt.show()

# %% [markdown]
# ### Traçar gráfico de violino com seaborn

# %%
plt.figure(figsize = (8,6))
ax = sns.violinplot(x='species',y='petal_length', data=df, hue='species', palette ='viridis', linewidth=1.5)

plt.title('Boxplot do dataset Iris')
plt.xlabel('Espécies')
plt.ylabel('Comprimento da Pétala')
plt.show()

# %% [markdown]
# #### Estimativa da densidade

# %%
plt.figure(figsize = (8,6))
sns.kdeplot(x='petal_length', data=df, hue='species', palette ='viridis', linewidth=1.5)

plt.title('Boxplot do dataset Iris')
plt.xlabel('Espécies')
plt.ylabel('Comprimento da Pétala')
plt.show()

# %% [markdown]
# #### Extensão do boxplot

# %%
plt.figure(figsize = (8,6))
ax = sns.boxenplot(x='petal_length', data=df, hue='species', palette ='viridis')

plt.title('Boxplot do dataset Iris')
plt.xlabel('Espécies')
plt.ylabel('Comprimento da Pétala')
plt.show()

# %% [markdown]
# ### 5. Visualização de Dados Categóricos
# #### Gráfico de Barras

# %%
categorias = ['A', 'B','C','D','E']
valores = [80,90,27,67,12]

# %%
plt.figure(figsize = (10,6))

plt.subplot(1,2,1)
plt.bar(categorias, valores, color=['r', 'b','k','g','y'])
plt.title('Gráfico de barras vertical')

plt.subplot(1,2,2)
plt.barh(categorias, valores, color=['r', 'b','k','g','y'])
plt.title('Gráfico de barras horizontal')

plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'Categorias': categorias, 'Valores':valores})
df
# Out:
#   Categorias  Valores
# 0          A       80
# 1          B       90
# 2          C       27
# 3          D       67
# 4          E       12

# %%
plt.figure(figsize = (10,6))
sns.barplot(x='Categorias',y='Valores', data=df, hue='Categorias', palette='mako')
plt.title('Gráfico de barras Seaborn')
plt.show()

# %% [markdown]
# #### Gráfico de Torta ou Pizza

# %%
plt.figure(figsize = (10,6))
plt.pie(valores, labels=categorias, autopct='%1.1f%%', #Exibe o percentual com uma casa decimal ()ex: 35,9%)
        startangle=45, colors=['c','m','y','r','g'])
plt.title('Gráfico de Torta')
plt.show()

# %% [markdown]
# #### Plotly (interativo)

# %%
import plotly.express as px
fig = px.pie(df,values='Valores', names='Categorias', title='Gráfico interativo',
            color_discrete_sequence=['cyan','magenta','yellow','red','green'])
fig.update_layout(width=400,height=400)
fig.show()

# %% [markdown]
# ### 6. Visualização de Relações entre Variáveis
# #### Scatter Plot

# %%
x = np.random.rand(100)
y = x + np.random.normal(0,0.1,100)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x,y, alpha=0.4)
plt.title('Scatter Plot - Relação entre X e Y')
plt.show()

# %%
df = pd.DataFrame({'X':x, 'Y':y})
#sns.jointplot(x='X', y='Y', data=df, kind='reg', height=8)
#sns.jointplot(x='X', y='Y', data=df, kind='scatter', height=8)
#sns.jointplot(x='X', y='Y', data=df, kind='kde', height=8)
#sns.jointplot(x='X', y='Y', data=df, kind='hex', height=8)
sns.jointplot(x='X', y='Y', data=df, kind='hist', height=8)

plt.suptitle('Scatter Plot com Regressão - Seaborn')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Heatmap (Matriz de Correlação)

# %%
#iris = sns.load_dataset('iris')
#corr = iris.corr(numeric_only=True)

data = pd.DataFrame(np.random.randn(100,5), columns=['A','B','C','D','E'])
corr = data.corr()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='flare',vmin=-1, linewidth=0.5, fmt='.2f')

plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# ### 6. Visualização de Séries Temporais

# %%
dates = pd.date_range('1984-01-01', periods=100)
values = np.cumsum(np.random.randn(100)) # Gerar uma série temporal

# %%
plt.figure(figsize=(8,6))
plt.plot(dates, values, marker = 'x', linestyle = '-')
plt.title('Série Temporal')
plt.xlabel('Data')
plt.ylabel('Valor')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Série temporal interativa com Plotly

# %%
df = pd.DataFrame({'Data':dates,'Valor':values})
fig = px.line(df, x = 'Data', y = 'Valor', title='Série Temporal Interativa')
fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# ### Intervalos de modelagem de séries temporais
# - A bibliteca tsmoothie serve para fazer a suavização de séries temporais e detecção de outliers de forma vetorizada.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tsmoothie.smoother import *

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x) + np.random.random(100) * 0.2

smoother = ConvolutionSmoother(window_len=10, window_type='ones')  #len = tamanho da janela de suavização, type = Janela uniforme = média móvel simples

smoother.smooth(y) # aplicou a suavização ao sinal Y

low, up = smoother.get_intervals('sigma_interval', n_sigma = 2) # sigma = tipo de intervalo (baseado no desvio padrão) | n_sigma = Intervalo com + ou - 2 desvios (95¨confiança 



plt.figure(figsize=(11,6))
plt.plot(smoother.smooth_data[0], linewidth=3, color = 'orange')
plt.plot(y, '.k')
plt.fill_between(range(len(smoother.data[0])),  #Eixo x
                 low[0], #limite inferior
                 up[0],  #limite superior
                 alpha=0.3) #Transparência
plt.show()

# %% [markdown]
# ### 7. Visualização de Dados Multidimensionais
# #### Pair Plot

# %%
iris = sns.load_dataset("iris")

# %%
sns.pairplot(iris, hue='species', height = 2.5)
plt.suptitle('Pair plot - relação entre variaveis', y = 1.02)
plt.show()

# %% [markdown]
# ### 8. Visualizações Interativas Avançadas
# #### Gráficos 3D com Matplotlib
#
# Para plotar gráficos 3D é necessário importar um submódulo do Matplotlib

# %%
from mpl_toolkits import mplot3d
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %% [markdown]
# ### Criando ambiente de plotagem do gráfico 3D

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')
ax.set_title("Ambiente de Plotagem 3D", fontsize=18)
ax.set_xlabel("Eixo X", fontsize=14)
ax.set_ylabel("Eixo Y", fontsize=14)
ax.set_zlabel("Eixo Z", fontsize=14)

plt.show()

# %% [markdown]
# ### Gráfico de linha no espaço 3D

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')

dim_z= np.linspace(0,18,1000)
dim_x= np.cos(dim_z)
dim_y= np.sin(dim_z)
ax.plot3D(dim_x, dim_y, dim_z, "red")

ax.set_title("Espiral de linha do plano 3D", fontsize=18)
ax.set_title("Ambiente de Plotagem 3D", fontsize=18)
ax.set_xlabel("Eixo X", fontsize=14)
ax.set_ylabel("Eixo Y", fontsize=14)
ax.set_zlabel("Eixo Z", fontsize=14)

ax.view_init(90, 90)

plt.show()

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 01

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 02

# %% [markdown]
# ### Gráfico de linha e de dispersão no espaço 3D
# - Adicionando mais informações na plotagem do gráfico
# - Plotando uma espiral 3d com pontos

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')

dim_z= np.linspace(0,18,1000)
dim_x= np.cos(dim_z)
dim_y= np.sin(dim_z)
ax.plot3D(dim_x, dim_y, dim_z, "black", linewidth=5, alpha=0.4 )

pontos_z = 18*np.random.random(120)
pontos_x = np.cos(pontos_z) + 0.1*np.random.randn(120)
pontos_y = np.sin(pontos_z) + 0.1*np.random.randn(120)
ax.scatter3D(pontos_x,pontos_y,pontos_z, c=pontos_z, cmap='Spectral')

ax.set_title("Espiral de linha do plano 3D", fontsize=18)
ax.set_title("Ambiente de Plotagem 3D", fontsize=18)
ax.set_xlabel("Eixo X", fontsize=14)
ax.set_ylabel("Eixo Y", fontsize=14)
ax.set_zlabel("Eixo Z", fontsize=14)

ax.view_init(10, 45)

plt.show()

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 01

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 02

# %% [markdown]
# ### Gráficos de contorno no Espaço 3D

# %%
def f(x,y):
    return np.sin(np.sqrt(x**2+y**2))

x = np.linspace(-6,6,30)
y = np.linspace(-6,6,30)
X, Y = np.meshgrid(x,y)
Z = f(X,Y)

fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap = 'magma')


ax.set_title("Grafico de contorno 3D", fontsize=18)
ax.view_init(45, 45)
plt.show()

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 01

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 02

# %% [markdown]
# ### Gráfico de superfície no Espaço 3

# %%
fig = plt.figure(figsize=(12,8))
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap = 'magma')
ax.plot_surface(X, Y, Z, rstride=89, cstride=25, cmap='winter', edgecolor='black')


ax.set_title("Grafico de superficie de espaço 3D", fontsize=18)
ax.view_init(45, 45)
plt.show()

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 01

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 02

# %% [markdown]
# ### Gráficos de barras no Espaço 3D

# %%
import random

fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')

num_barras = 15
x_pos = random.sample(range(20), num_barras)
y_pos = random.sample(range(20), num_barras)
z_pos = [0] * num_barras

x_size = np.ones(num_barras)
y_size = np.ones(num_barras)
z_size = random.sample(range(20), num_barras)

ax.bar3d(x_pos, y_pos, z_pos, x_size, y_size, z_size, color='slateblue')

ax.set_title("Grafico de barras 3D", fontsize=18)
ax.view_init(45, 45)
plt.show()

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 01

# %% [markdown]
# ### Parâmetros de Ângulo - Ex 02

# %% [markdown]
# #### Gráfico 3D Interativo

# %%
t = np.linspace(1000,2,500)
x,y,z=np.cos(t), np.sin(t), t

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, mode = 'markers', marker=dict(size=20, color = z, colorscale='magma'))])

fig.update_layout(title='Grafico 3D de intervalo', width = 1200, height = 800, scene=dict(xaxis_title="X", yaxis_title="Y", zaxis_title="Z"))

# %% [markdown]
# ## Dashboard Interativo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# Configuração inicial
plt.style.use('seaborn-v0_8')
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.titleweight'] = 'bold'

# Carregar dados
iris = load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target_names[iris.target]

# 1. Cabeçalho do Dashboard
plt.figure(figsize=(14, 1))
plt.text(0.5, 0.5, 'Dashboard - Análise do Conjunto de dados Iris', 
         ha='center', va='center', 
         fontsize=24, fontweight='bold', color='#2e86ab')
plt.axis('off')
plt.show()

# 2. Visualização Geral (Subplots)
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('Principais Análises', y=1.02, fontsize=18, fontweight='bold')

# Gráfico 1: Histograma
sns.histplot(data=iris_df, x="sepal length (cm)", hue="species", 
             kde=True, ax=axes[0, 0], palette="husl")
axes[0, 0].set_title('Distribuição do Comprimento da Sépala')

# Gráfico 2: Boxplot
sns.boxplot(data=iris_df, x="species", y="petal width (cm)", 
            hue="species", palette="husl", legend=False, ax=axes[0, 1])
axes[0, 1].set_title('Largura da Pétala por Espécie')

# Gráfico 3: Scatter Plot
sns.scatterplot(data=iris_df, x="sepal width (cm)", y="petal length (cm)", 
                hue="species", style="species", s=100, 
                palette="husl", ax=axes[1, 0])
axes[1, 0].set_title('Relação Sépala vs Pétala')

# Gráfico 4: Heatmap de Correlação
corr = iris_df.iloc[:, :4].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", 
            center=0, ax=axes[1, 1], fmt=".2f")
axes[1, 1].set_title('Matriz de Correlação')

plt.tight_layout()
plt.show()

# 3. Gráfico Adicional (Pair Plot)
plt.figure(figsize=(12, 8))
sns.pairplot(iris_df, hue="species", palette="husl", 
             height=2.5, plot_kws={'s': 80})
plt.suptitle('Relações entre Todas as Variáveis', y=1.02)
plt.show()

# 4. Estatísticas Resumidas
print("\n Métricas Estatísticas por Espécie:")
stats = iris_df.groupby('species').agg(['mean', 'std', 'min', 'max']).round(2)
display(stats.style.background_gradient(cmap='Blues', axis=0))
# Out:
#  Métricas Estatísticas por Espécie:
# <style type="text/css">
# #T_79117_row0_col0, #T_79117_row0_col1, #T_79117_row0_col2, #T_79117_row0_col3, #T_79117_row0_col8, #T_79117_row0_col9, #T_79117_row0_col10, #T_79117_row0_col11, #T_79117_row0_col12, #T_79117_row0_col13, #T_79117_row0_col14, #T_79117_row0_col15, #T_79117_row1_col4, #T_79117_row1_col5, #T_79117_row1_col6, #T_79117_row1_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_79117_row0_col4, #T_79117_row0_col5, #T_79117_row0_col6, #T_79117_row0_col7, #T_79117_row1_col2, #T_79117_row2_col0, #T_79117_row2_col1, #T_79117_row2_col2, #T_79117_row2_col3, #T_79117_row2_col8, #T_79117_row2_col9, #T_79117_row2_col10, #T_79117_row2_col11, #T_79117_row2_col12, #T_79117_row2_col13, #T_79117_row2_col14, #T_79117_row2_col15 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_79117_row1_col0, #T_79117_row1_col1 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_79117_row1_col3, #T_79117_row1_col10 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_79117_row1_col8 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_79117_row1_col9 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_79117_row1_col11 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_79117_row1_col12 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_79117_row1_col13 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_79117_row1_col14 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_79117_row1_col15 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_79117_row2_col4 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_79117_row2_col5 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_79117_row2_col6 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_79117_row2_col7 {
#   background-color: #94c4df;
#   color: #000000;
# }
# </style>
# <table id="T_79117">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79117_level0_col0" class="col_heading level0 col0" colspan="4">sepal length (cm)</th>
#       <th id="T_79117_level0_col4" class="col_heading level0 col4" colspan="4">sepal width (cm)</th>
#       <th id="T_79117_level0_col8" class="col_heading level0 col8" colspan="4">petal length (cm)</th>
#       <th id="T_79117_level0_col12" class="col_heading level0 col12" colspan="4">petal width (cm)</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_79117_level1_col0" class="col_heading level1 col0" >mean</th>
#       <th id="T_79117_level1_col1" class="col_heading level1 col1" >std</th>
#       <th id="T_79117_level1_col2" class="col_heading level1 col2" >min</th>
#       <th id="T_79117_level1_col3" class="col_heading level1 col3" >max</th>
#       <th id="T_79117_level1_col4" class="col_heading level1 col4" >mean</th>
#       <th id="T_79117_level1_col5" class="col_heading level1 col5" >std</th>
#       <th id="T_79117_level1_col6" class="col_heading level1 col6" >min</th>
#       <th id="T_79117_level1_col7" class="col_heading level1 col7" >max</th>
#       <th id="T_79117_level1_col8" class="col_heading level1 col8" >mean</th>
#       <th id="T_79117_level1_col9" class="col_heading level1 col9" >std</th>
#       <th id="T_79117_level1_col10" class="col_heading level1 col10" >min</th>
#       <th id="T_79117_level1_col11" class="col_heading level1 col11" >max</th>
#       <th id="T_79117_level1_col12" class="col_heading level1 col12" >mean</th>
#       <th id="T_79117_level1_col13" class="col_heading level1 col13" >std</th>
#       <th id="T_79117_level1_col14" class="col_heading level1 col14" >min</th>
#       <th id="T_79117_level1_col15" class="col_heading level1 col15" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >species</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79117_level0_row0" class="row_heading level0 row0" >setosa</th>
#       <td id="T_79117_row0_col0" class="data row0 col0" >5.010000</td>
#       <td id="T_79117_row0_col1" class="data row0 col1" >0.350000</td>
#       <td id="T_79117_row0_col2" class="data row0 col2" >4.300000</td>
#       <td id="T_79117_row0_col3" class="data row0 col3" >5.800000</td>
#       <td id="T_79117_row0_col4" class="data row0 col4" >3.430000</td>
#       <td id="T_79117_row0_col5" class="data row0 col5" >0.380000</td>
#       <td id="T_79117_row0_col6" class="data row0 col6" >2.300000</td>
#       <td id="T_79117_row0_col7" class="data row0 col7" >4.400000</td>
#       <td id="T_79117_row0_col8" class="data row0 col8" >1.460000</td>
#       <td id="T_79117_row0_col9" class="data row0 col9" >0.170000</td>
#       <td id="T_79117_row0_col10" class="data row0 col10" >1.000000</td>
#       <td id="T_79117_row0_col11" class="data row0 col11" >1.900000</td>
#       <td id="T_79117_row0_col12" class="data row0 col12" >0.250000</td>
#       <td id="T_79117_row0_col13" class="data row0 col13" >0.110000</td>
#       <td id="T_79117_row0_col14" class="data row0 col14" >0.100000</td>
#       <td id="T_79117_row0_col15" class="data row0 col15" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_79117_level0_row1" class="row_heading level0 row1" >versicolor</th>
#       <td id="T_79117_row1_col0" class="data row1 col0" >5.940000</td>
#       <td id="T_79117_row1_col1" class="data row1 col1" >0.520000</td>
#       <td id="T_79117_row1_col2" class="data row1 col2" >4.900000</td>
#       <td id="T_79117_row1_col3" class="data row1 col3" >7.000000</td>
#       <td id="T_79117_row1_col4" class="data row1 col4" >2.770000</td>
#       <td id="T_79117_row1_col5" class="data row1 col5" >0.310000</td>
#       <td id="T_79117_row1_col6" class="data row1 col6" >2.000000</td>
#       <td id="T_79117_row1_col7" class="data row1 col7" >3.400000</td>
#       <td id="T_79117_row1_col8" class="data row1 col8" >4.260000</td>
#       <td id="T_79117_row1_col9" class="data row1 col9" >0.470000</td>
#       <td id="T_79117_row1_col10" class="data row1 col10" >3.000000</td>
#       <td id="T_79117_row1_col11" class="data row1 col11" >5.100000</td>
#       <td id="T_79117_row1_col12" class="data row1 col12" >1.330000</td>
#       <td id="T_79117_row1_col13" class="data row1 col13" >0.200000</td>
#       <td id="T_79117_row1_col14" class="data row1 col14" >1.000000</td>
#       <td id="T_79117_row1_col15" class="data row1 col15" >1.800000</td>
#     </tr>
#     <tr>
#       <th id="T_79117_level0_row2" class="row_heading level0 row2" >virginica</th>
#       <td id="T_79117_row2_col0" class="data row2 col0" >6.590000</td>
#       <td id="T_79117_row2_col1" class="data row2 col1" >0.640000</td>
#       <td id="T_79117_row2_col2" class="data row2 col2" >4.900000</td>
#       <td id="T_79117_row2_col3" class="data row2 col3" >7.900000</td>
#       <td id="T_79117_row2_col4" class="data row2 col4" >2.970000</td>
#       <td id="T_79117_row2_col5" class="data row2 col5" >0.320000</td>
#       <td id="T_79117_row2_col6" class="data row2 col6" >2.200000</td>
#       <td id="T_79117_row2_col7" class="data row2 col7" >3.800000</td>
#       <td id="T_79117_row2_col8" class="data row2 col8" >5.550000</td>
#       <td id="T_79117_row2_col9" class="data row2 col9" >0.550000</td>
#       <td id="T_79117_row2_col10" class="data row2 col10" >4.500000</td>
#       <td id="T_79117_row2_col11" class="data row2 col11" >6.900000</td>
#       <td id="T_79117_row2_col12" class="data row2 col12" >2.030000</td>
#       <td id="T_79117_row2_col13" class="data row2 col13" >0.270000</td>
#       <td id="T_79117_row2_col14" class="data row2 col14" >1.40000
